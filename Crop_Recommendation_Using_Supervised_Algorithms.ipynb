# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Crop_Recommendation.csv')
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90        42.0         43    20.879744  82.002744  6.502985
# 1           85        58.0         41    21.770462  80.319644  7.038096
# 2           60        55.0         44    23.004459  82.320763  7.840207
# 3           74        35.0         40    26.491096  80.158363  6.980401
# 4           78        42.0         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107        34.0         32    26.774637  66.413269  6.780064
# 2196        99        15.0         27    27.417112  56.636362  6.086922
# 2197       118        33.0         30    24.131797  67.225123  6.362608
# 2198       117        32.0         34    26.272418  52.127394  6.758793
# 2199       104        18.0         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# ...

# %%
#Exploratory_data_analysis
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   Phosphorus   2199 non-null   float64
#  2   Potassium    2200 non-null   int64
#  3   Temperature  2193 non-null   float64
#  4   Humidity     2192 non-null   float64
#  5   pH_Value     2194 non-null   float64
#  6   Rainfall     2195 non-null   float64
#  7   Crop         2200 non-null   object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 137.6+ KB

# %%
df.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90        42.0         43    20.879744  82.002744  6.502985
# 1        85        58.0         41    21.770462  80.319644  7.038096
# 2        60        55.0         44    23.004459  82.320763  7.840207
# 3        74        35.0         40    26.491096  80.158363  6.980401
# 4        78        42.0         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536  Rice
# 1  226.655537  Rice
# 2  263.964248  Rice
# 3  242.864034  Rice
# 4  262.717340  Rice

# %%
df.tail()
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 2195       107        34.0         32    26.774637  66.413269  6.780064
# 2196        99        15.0         27    27.417112  56.636362  6.086922
# 2197       118        33.0         30    24.131797  67.225123  6.362608
# 2198       117        32.0         34    26.272418  52.127394  6.758793
# 2199       104        18.0         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 2195  177.774507  Coffee
# 2196  127.924610  Coffee
# 2197  173.322839  Coffee
# 2198  127.175293  Coffee
# 2199  140.937041  Coffee

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium  Temperature     Humidity  \
# count  2200.000000  2199.000000  2200.000000  2193.000000  2192.000000
# mean     50.551818    53.376535    48.149091    25.616298    71.483751
# std      36.917334    32.987026    50.647931     5.067266    22.229120
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.766430    60.261953
# 50%      37.000000    51.000000    32.000000    25.601540    80.464995
# 75%      84.250000    68.000000    49.000000    28.562122    89.935185
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#           pH_Value     Rainfall
# count  2194.000000  2195.000000
# mean      6.469140   103.488279
# std       0.773323    55.004364
# min       3.504752    20.211267
# 25%       5.970677    64.544549
# 50%       6.426829    94.781896
# 75%       6.923909   124.402507
# max       9.935091   298.560117

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.isnull().sum()
# Out:
# Nitrogen       0
# Phosphorus     1
# Potassium      0
# Temperature    7
# Humidity       8
# pH_Value       6
# Rainfall       5
# Crop           0
# dtype: int64

# %%
#filling_missing_values
from sklearn.impute import SimpleImputer
impute=SimpleImputer(missing_values=np.nan,strategy='mean')
for col in df.columns:
  df.iloc[:,1:7]=impute.fit_transform(df.iloc[:,1:7])

# %%
i=df['Crop']
j=df['Rainfall']
k=df['Humidity']

# %%
#lineplot
plt.plot(i)

# %%
#scatterplot
plt.scatter(k,i)

# %%
#barplot
plt.bar(i,height=2,width=15)
# Out:
# <BarContainer object of 2200 artists>

# %%
#histogram
plt.hist(i)
# Out:
# (array([300., 200., 200., 200., 200., 200., 200., 200., 200., 300.]),
#  array([ 0. ,  2.1,  4.2,  6.3,  8.4, 10.5, 12.6, 14.7, 16.8, 18.9, 21. ]),
#  <BarContainer object of 10 artists>)

# %%
#barplot_using_seaborn
sns.barplot(x=j,y=i,data=df)
# Out:
# <Axes: xlabel='Rainfall', ylabel='Crop'>

# %%
#distribution_plot
sns.displot(i)

# %%
#pairplot
sns.pairplot(data=df,hue='Crop')

# %%
#counterplot
sns.countplot(x=i,data=df)
# Out:
# <Axes: xlabel='Crop', ylabel='count'>

# %%
#boxplot_using_for_loop
plt.figure(figsize=(20,15))
plotnumber=1
for col in df.columns:
  if plotnumber<=8:
    plt.subplot(5,5,plotnumber)
    sns.boxplot(df[col])
    plt.xlabel(col,fontsize=15)
  plotnumber+=1
plt.tight_layout()
plt.show()

# %%
#minimum_amount_of_rainfall
r=min(df['Rainfall'])
r
# Out:
# 20.21126747

# %%
#finding_the_crop_recommended_in_minimum_amount_of_rainfall
N=df[df['Rainfall']==r]
N[['Rainfall','Crop']]
# Out:
#        Rainfall       Crop
# 1444  20.211267  Muskmelon

# %%
#finding_the_crop_recommended_in_minimum_humidity_and_temperature
b=min(df['Humidity'])
c=min(df['Temperature'])
L=df[(df['Humidity']==b) | (df['Temperature']==c)]
L[['Temperature','Humidity','Crop']]
# Out:
#       Temperature   Humidity      Crop
# 230     20.566019  14.258040  ChickPea
# 1214     8.825675  82.897537    Grapes

# %%
#Label_Encoding
from sklearn.preprocessing import LabelEncoder
a=LabelEncoder()
columns=df.select_dtypes(include=['object']).columns
for col in columns:
  df[col]=a.fit_transform(df[col])
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90        42.0         43    20.879744  82.002744  6.502985
# 1           85        58.0         41    21.770462  80.319644  7.038096
# 2           60        55.0         44    23.004459  82.320763  7.840207
# 3           74        35.0         40    26.491096  80.158363  6.980401
# 4           78        42.0         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107        34.0         32    26.774637  66.413269  6.780064
# 2196        99        15.0         27    27.417112  56.636362  6.086922
# 2197       118        33.0         30    24.131797  67.225123  6.362608
# 2198       117        32.0         34    26.272418  52.127394  6.758793
# 2199       104        18.0         30    23.603016  60.396475  6.779833
#
#         Rainfall  Crop
# 0     202.935536    20
# 1     226.655537    20
# 2     263.964248    20
# ...

# %%
#heatmap
plt.figure(figsize=(20,15))
corr=df.corr()
sns.heatmap(corr,annot=True,fmt='.2g',linewidth=1)
plt.tight_layout()
plt.show()

# %%
x=df.drop('Crop',axis=1)
y=df['Crop']

# %%
#training_and_testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)
x_train
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 1567        27       120.0        200    21.452787  90.745319  6.110219
# 2031        81        36.0         38    23.765547  87.983299  6.334838
# 2073        90        59.0         35    24.251335  89.864541  7.098228
# 1374        81        16.0         45    26.904357  86.254262  6.727468
# 279         47        80.0         77    17.182484  16.428918  7.561108
# ...        ...         ...        ...          ...        ...       ...
# 1033       102        71.0         48    28.654563  79.286937  5.695268
# 1731        34        68.0         51    27.347349  94.177567  6.687088
# 763         35        64.0         15    28.474423  63.536045  6.500145
# 835         39        65.0         23    25.434598  69.126134  7.685959
# 1653        14        22.0          9    17.249446  91.137728  6.543192
#
#         Rainfall
# 1567  116.703658
# 2031  150.316615
# 2073  175.174211
# 1374   59.759800
# ...

# %%
#support_vector_machine
from sklearn.svm import SVC
clf=SVC(kernel='rbf')
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
#Testing_accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9727272727272728

# %%
y_pred1=clf.predict(x_train)

# %%
#Training_accuracy_score
accuracy_score(y_pred1,y_train)
# Out:
# 0.975

# %%
#DecisionTree_Algorithm
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier(criterion='entropy')
clf1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred2=clf1.predict(x_test)

# %%
#Testing_accuracy_score
accuracy_score(y_pred2,y_test)
# Out:
# 0.990909090909091

# %%
Y_Pred=clf1.predict(x_train)

# %%
#Training_accuracy_score
accuracy_score(Y_Pred,y_train)
# Out:
# 1.0

# %%
#Random_Forest_algorithm
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(random_state=40,n_jobs=-1,max_depth=5,n_estimators=80,oob_score=True)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=80, n_jobs=-1, oob_score=True,
#                        random_state=40)

# %%
Y_pred=rf.predict(x_test)

# %%
#Testing_accuracy_score
accuracy_score(Y_pred,y_test)
# Out:
# 0.9772727272727273

# %%
Y_PRed=rf.predict(x_train)

# %%
#Training_accuracy_score
accuracy_score(Y_PRed,y_train)
# Out:
# 0.9863636363636363

# %%
#Linear_Regression
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
Y_pred1=reg.predict(x)

# %%
#score
reg.score(x,y)
# Out:
# 0.29673510882502596

# %%
#coefficient
reg.coef_
# Out:
# array([-3.05433361e-02, -8.87230646e-02, -9.85222434e-03,  1.10063338e-02,
#         5.33064615e-02, -5.93773151e-01, -2.25112152e-04])

# %%
#intercept
reg.intercept_
# Out:
# 17.026137537490538

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Y_pred2=reg.predict(x_test)

# %%
#r2_score
r2_score(Y_pred2,y_test)
# Out:
# -1.406531052939386

# %%
#mean_absolute_error
mean_absolute_error(Y_pred2,y_test)
# Out:
# 4.137279288631537

# %%
#mean_squared_error
mean_squared_error(Y_pred2,y_test)
# Out:
# 27.451817553009647

# %%
#root_mean_squared_error
np.sqrt(mean_squared_error(Y_pred2,y_test))
# Out:
# 5.2394482107383835

# %%
#Logistic_Regression
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred3=log.predict(x_test)

# %%
#Testing_accuracy_score
accuracy_score(y_pred3,y_test)
# Out:
# 0.9613636363636363

# %%
y_pred4=log.predict(x_train)

# %%
#Training_accuracy_score
accuracy_score(y_pred4,y_train)
# Out:
# 0.9670454545454545

# %%
#KNearestNeighbor_algorithm
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred4=knn.predict(x_test)

# %%
#Testing_accuracy_score
accuracy_score(y_pred4,y_test)
# Out:
# 0.9727272727272728

# %%
y_pred5=knn.predict(x_train)

# %%
#Training_accuracy_score
accuracy_score(y_pred5,y_train)
# Out:
# 0.9875

# %%
#Naive_Bayes_algorithm
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred6=mnb.predict(x_test)

# %%
#Testing_accuracy_score
accuracy_score(y_test,y_pred6)
# Out:
# 0.8772727272727273

# %%
y_pred7=mnb.predict(x_train)

# %%
#Training_accuracy_score
accuracy_score(y_pred7,y_train)
# Out:
# 0.8914772727272727
